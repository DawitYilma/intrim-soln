# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tele=pd.read_excel('Week2_challenge_data_source.xlsx')
tele.head()
# Out:
#               Bearer Id               Start  Start ms                 End  \
# 0  13114483460844900352 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31
# 1  13114483482878900224 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48
# 2  13114483484080500736 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13
# 3  13114483485442799616 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35
# 4  13114483499480700928 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32
#
#    End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0   662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#   Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0   9164566995485190  ...          15854611.0           2501332.0
# 1            L77566A  ...          20247395.0          19111729.0
# 2            D42335A  ...          19725661.0          14699576.0
# 3            T21824A  ...          21388122.0          15146643.0
# 4            D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
tele['Handset Type'].value_counts().head(10)
# Out:
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset Type, dtype: int64

# %%
tele['Handset Manufacturer'].value_counts().head(3)
# Out:
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: Handset Manufacturer, dtype: int64

# %%
for t in tele['Handset Manufacturer'].value_counts().head(3):
    print(tele['Handset Type'].value_counts().head(15))
# Out:
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Samsung Galaxy A5 Sm-A520F       3724
# Samsung Galaxy J5 (Sm-J530)      3696
# Samsung Galaxy J3 (Sm-J330)      3484
# Samsung Galaxy S7 (Sm-G930X)     3199
# Apple iPhone 8 Plus (A1897)      3016
# Name: Handset Type, dtype: int64
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Samsung Galaxy A5 Sm-A520F       3724
# Samsung Galaxy J5 (Sm-J530)      3696
# Samsung Galaxy J3 (Sm-J330)      3484
# Samsung Galaxy S7 (Sm-G930X)     3199
# Apple iPhone 8 Plus (A1897)      3016
# Name: Handset Type, dtype: int64
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Samsung Galaxy A5 Sm-A520F       3724
# Samsung Galaxy J5 (Sm-J530)      3696
# Samsung Galaxy J3 (Sm-J330)      3484
# Samsung Galaxy S7 (Sm-G930X)     3199
# Apple iPhone 8 Plus (A1897)      3016
# Name: Handset Type, dtype: int64

# %%
tele.groupby('MSISDN/Number')['Dur. (ms)'].describe().unstack()
# Out:
#        MSISDN/Number
# count  3.360100e+10          1.0
#        3.360100e+10          1.0
#        3.360100e+10          1.0
#        3.360101e+10          1.0
#        3.360101e+10          2.0
#        3.360101e+10          2.0
#        3.360101e+10          2.0
#        3.360101e+10          1.0
#        3.360101e+10          2.0
#        3.360102e+10          1.0
#        3.360102e+10          1.0
#        3.360102e+10          1.0
#        3.360102e+10          1.0
#        3.360102e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          1.0
#        3.360103e+10          2.0
#        3.360103e+10          2.0
#        3.360104e+10          1.0
#        3.360104e+10          1.0
#        3.360104e+10          1.0
#        3.360104e+10          1.0
#        3.360104e+10          1.0
#        3.360104e+10          1.0
#        3.360105e+10          1.0
#        3.360105e+10          3.0
#                           ...
# max    3.378980e+10     160202.0
#        3.378981e+10     124538.0
#        3.378983e+10     139292.0
#        3.378983e+10     108410.0
#        3.378984e+10      29263.0
#        3.378984e+10     227852.0
#        3.378986e+10      33395.0
#        3.378988e+10      47989.0
#        3.378988e+10      86400.0
#        3.378988e+10     159795.0
#        3.378988e+10     175746.0
#        3.378988e+10     248637.0
#        3.378989e+10     135558.0
#        3.378989e+10     173035.0
#        3.378991e+10      44199.0
#        3.378991e+10      86399.0
#        3.378991e+10      98294.0
#        3.378992e+10      54339.0
#        3.378994e+10      36812.0
#        3.378995e+10     120184.0
#        3.378996e+10      98826.0
#        3.378996e+10     157069.0
#        3.378997e+10     160461.0
#        3.378998e+10     178525.0
#        3.379000e+10       8810.0
#        3.379000e+10     140988.0
#        4.188282e+10     523005.0
#        3.197021e+12     877385.0
#        3.370000e+14     253030.0
#        8.823971e+14     869844.0
# Length: 854856, dtype: float64

# %%
tele.groupby('MSISDN/Number')['Total UL (Bytes)'].describe().unstack()
# Out:
#        MSISDN/Number
# count  3.360100e+10     1.000000e+00
#        3.360100e+10     1.000000e+00
#        3.360100e+10     1.000000e+00
#        3.360101e+10     1.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     1.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     2.000000e+00
#        3.360103e+10     2.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360105e+10     1.000000e+00
#        3.360105e+10     3.000000e+00
#                             ...
# max    3.378980e+10     4.901769e+06
#        3.378981e+10     4.901769e+06
#        3.378983e+10     4.901769e+06
#        3.378983e+10     4.901769e+06
#        3.378984e+10     4.901769e+06
#        3.378984e+10     4.901769e+06
#        3.378986e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378989e+10     4.901769e+06
#        3.378989e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378992e+10     4.901769e+06
#        3.378994e+10     4.901769e+06
#        3.378995e+10     4.901769e+06
#        3.378996e+10     4.901769e+06
#        3.378996e+10     4.901769e+06
#        3.378997e+10     4.901769e+06
#        3.378998e+10     4.901769e+06
#        3.379000e+10     4.901769e+06
#        3.379000e+10     4.901769e+06
#        4.188282e+10     4.901769e+06
#        3.197021e+12     4.901769e+06
#        3.370000e+14     4.901769e+06
#        8.823971e+14     4.901769e+06
# Length: 854856, dtype: float64

# %%
tele.groupby('MSISDN/Number')['Total DL (Bytes)'].describe().unstack()
# Out:
#        MSISDN/Number
# count  3.360100e+10     1.000000e+00
#        3.360100e+10     1.000000e+00
#        3.360100e+10     1.000000e+00
#        3.360101e+10     1.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360101e+10     1.000000e+00
#        3.360101e+10     2.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360102e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     1.000000e+00
#        3.360103e+10     2.000000e+00
#        3.360103e+10     2.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360104e+10     1.000000e+00
#        3.360105e+10     1.000000e+00
#        3.360105e+10     3.000000e+00
#                             ...
# max    3.378980e+10     4.901769e+06
#        3.378981e+10     4.901769e+06
#        3.378983e+10     4.901769e+06
#        3.378983e+10     4.901769e+06
#        3.378984e+10     4.901769e+06
#        3.378984e+10     4.901769e+06
#        3.378986e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378988e+10     4.901769e+06
#        3.378989e+10     4.901769e+06
#        3.378989e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378991e+10     4.901769e+06
#        3.378992e+10     4.901769e+06
#        3.378994e+10     4.901769e+06
#        3.378995e+10     4.901769e+06
#        3.378996e+10     4.901769e+06
#        3.378996e+10     4.901769e+06
#        3.378997e+10     4.901769e+06
#        3.378998e+10     4.901769e+06
#        3.379000e+10     4.901769e+06
#        3.379000e+10     4.901769e+06
#        4.188282e+10     4.901769e+06
#        3.197021e+12     4.901769e+06
#        3.370000e+14     4.901769e+06
#        8.823971e+14     4.901769e+06
# Length: 854856, dtype: float64

# %% [markdown]
# # Non graphical Univariate analysis

# %%
tele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
# Bearer Id                                   150001 non-null object
# Start                                       150000 non-null datetime64[ns]
# Start ms                                    150000 non-null float64
# End                                         150000 non-null datetime64[ns]
# End ms                                      150000 non-null float64
# Dur. (ms)                                   150000 non-null float64
# IMSI                                        149431 non-null float64
# MSISDN/Number                               148935 non-null float64
# IMEI                                        149429 non-null float64
# Last Location Name                          148848 non-null object
# Avg RTT DL (ms)                             122172 non-null float64
# Avg RTT UL (ms)                             122189 non-null float64
# Avg Bearer TP DL (kbps)                     150000 non-null float64
# Avg Bearer TP UL (kbps)                     150000 non-null float64
# TCP DL Retrans. Vol (Bytes)                 61855 non-null float64
# TCP UL Retrans. Vol (Bytes)                 53352 non-null float64
# DL TP < 50 Kbps (%)                         149247 non-null float64
# 50 Kbps < DL TP < 250 Kbps (%)              149247 non-null float64
# 250 Kbps < DL TP < 1 Mbps (%)               149247 non-null float64
# DL TP > 1 Mbps (%)                          149247 non-null float64
# UL TP < 10 Kbps (%)                         149209 non-null float64
# 10 Kbps < UL TP < 50 Kbps (%)               149209 non-null float64
# 50 Kbps < UL TP < 300 Kbps (%)              149209 non-null float64
# UL TP > 300 Kbps (%)                        149209 non-null float64
# HTTP DL (Bytes)                             68527 non-null float64
# HTTP UL (Bytes)                             68191 non-null float64
# Activity Duration DL (ms)                   150000 non-null float64
# Activity Duration UL (ms)                   150000 non-null float64
# Dur. (ms).1                                 150000 non-null float64
# Handset Manufacturer                        149429 non-null object
# Handset Type                                149429 non-null object
# Nb of sec with 125000B < Vol DL             52463 non-null float64
# Nb of sec with 1250B < Vol UL < 6250B       57107 non-null float64
# Nb of sec with 31250B < Vol DL < 125000B    56415 non-null float64
# Nb of sec with 37500B < Vol UL              19747 non-null float64
# Nb of sec with 6250B < Vol DL < 31250B      61684 non-null float64
# Nb of sec with 6250B < Vol UL < 37500B      38158 non-null float64
# Nb of sec with Vol DL < 6250B               149246 non-null float64
# Nb of sec with Vol UL < 1250B               149208 non-null float64
# Social Media DL (Bytes)                     150001 non-null float64
# Social Media UL (Bytes)                     150001 non-null float64
# Google DL (Bytes)                           150001 non-null float64
# Google UL (Bytes)                           150001 non-null float64
# Email DL (Bytes)                            150001 non-null float64
# Email UL (Bytes)                            150001 non-null float64
# Youtube DL (Bytes)                          150001 non-null float64
# Youtube UL (Bytes)                          150001 non-null float64
# Netflix DL (Bytes)                          150001 non-null float64
# Netflix UL (Bytes)                          150001 non-null float64
# Gaming DL (Bytes)                           150001 non-null float64
# Gaming UL (Bytes)                           150001 non-null float64
# Other DL (Bytes)                            150001 non-null float64
# Other UL (Bytes)                            150001 non-null float64
# Total UL (Bytes)                            150000 non-null float64
# Total DL (Bytes)                            150000 non-null float64
# dtypes: datetime64[ns](2), float64(49), object(4)
# memory usage: 62.9+ MB

# %%
# make a list of the categoricla variables that contain missing values
vars_with_na = [var for var in tele if tele[var].isnull().sum()>1 and tele[var].dtypes=='O']

# print the variable name and the percentage of missing values
for var in vars_with_na:
    print(var, np.round(tele[var].isnull().mean(), 3),  ' % missing values')
# Out:
# Last Location Name 0.008  % missing values
# Handset Manufacturer 0.004  % missing values
# Handset Type 0.004  % missing values

# %%
# function to replace NA in categorical variables
def fill_categorical_na(df, var_list):
    X = df.copy()
    X[var_list] = df[var_list].fillna('Missing')
    return X

# %%
# replace missing values with new label: "Missing"
tele= fill_categorical_na(tele, vars_with_na)


# check that we have no missing information in the engineered variables
tele[vars_with_na].isnull().sum()
# Out:
# Last Location Name      0
# Handset Manufacturer    0
# Handset Type            0
# dtype: int64

# %%
num_vars = [var for var in tele.columns if tele[var].dtypes != 'O']

print('Number of numerical variables: ', len(num_vars))

# visualise the numerical variables
tele[num_vars].head()
# Out:
# Number of numerical variables:  51
#                 Start  Start ms                 End  End ms  Dur. (ms)  \
# 0 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31   662.0  1823652.0
# 1 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48   606.0  1365104.0
# 2 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13   652.0  1361762.0
# 3 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35   171.0  1321509.0
# 4 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32   954.0  1089009.0
#
#            IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# 0  2.082014e+14   3.366496e+10  3.552121e+13             42.0
# 1  2.082019e+14   3.368185e+10  3.579401e+13             65.0
# 2  2.082003e+14   3.376063e+10  3.528151e+13              NaN
# 3  2.082014e+14   3.375034e+10  3.535661e+13              NaN
# 4  2.082014e+14   3.369980e+10  3.540701e+13              NaN
#
#    Avg RTT UL (ms)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0              5.0  ...          15854611.0           2501332.0
# 1              5.0  ...          20247395.0          19111729.0
# 2              NaN  ...          19725661.0          14699576.0
# 3              NaN  ...          21388122.0          15146643.0
# 4              NaN  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 51 columns]

# %%
# list of variables that contain year information
year_vars = [var for var in num_vars if 'Yr' in var or 'Year' in var]

year_vars
# Out:
# []

# %%
#  list of discrete variables
discrete_vars = [var for var in num_vars if len(tele[var].unique())<20 and var not in year_vars+['Id']]

print('Number of discrete variables: ', len(discrete_vars))
# Out:
# Number of discrete variables:  0

# %%
# list of continuous variables
cont_vars = [var for var in num_vars if var not in discrete_vars+year_vars+['Id']]

print('Number of continuous variables: ', len(cont_vars))
# Out:
# Number of continuous variables:  51

# %%
# make a list of the numerical variables that contain missing values
vars_with_na = [var for var in tele.columns if tele[var].isnull().sum()>1 and tele[var].dtypes!='O']

# print the variable name and the percentage of missing values
for var in vars_with_na:
    print(var, np.round(tele[var].isnull().mean(), 3),  ' % missing values')
# Out:
# IMSI 0.004  % missing values
# MSISDN/Number 0.007  % missing values
# IMEI 0.004  % missing values
# Avg RTT DL (ms) 0.186  % missing values
# Avg RTT UL (ms) 0.185  % missing values
# TCP DL Retrans. Vol (Bytes) 0.588  % missing values
# TCP UL Retrans. Vol (Bytes) 0.644  % missing values
# DL TP < 50 Kbps (%) 0.005  % missing values
# 50 Kbps < DL TP < 250 Kbps (%) 0.005  % missing values
# 250 Kbps < DL TP < 1 Mbps (%) 0.005  % missing values
# DL TP > 1 Mbps (%) 0.005  % missing values
# UL TP < 10 Kbps (%) 0.005  % missing values
# 10 Kbps < UL TP < 50 Kbps (%) 0.005  % missing values
# 50 Kbps < UL TP < 300 Kbps (%) 0.005  % missing values
# UL TP > 300 Kbps (%) 0.005  % missing values
# HTTP DL (Bytes) 0.543  % missing values
# HTTP UL (Bytes) 0.545  % missing values
# Nb of sec with 125000B < Vol DL 0.65  % missing values
# Nb of sec with 1250B < Vol UL < 6250B 0.619  % missing values
# Nb of sec with 31250B < Vol DL < 125000B 0.624  % missing values
# Nb of sec with 37500B < Vol UL 0.868  % missing values
# Nb of sec with 6250B < Vol DL < 31250B 0.589  % missing values
# Nb of sec with 6250B < Vol UL < 37500B 0.746  % missing values
# Nb of sec with Vol DL < 6250B 0.005  % missing values
# Nb of sec with Vol UL < 1250B 0.005  % missing values

# %%
# replace the missing values
for var in vars_with_na:
    
    # calculate the mean
    mean_val = tele[var].mean()
    
    tele[var+'_na'] = np.where(tele[var].isnull(), 1, 0)
    tele[var].fillna(mean_val, inplace=True)
    


# check that we have no more missing values in the engineered variables
tele[vars_with_na].isnull().sum()
# Out:
# IMSI                                        0
# MSISDN/Number                               0
# IMEI                                        0
# Avg RTT DL (ms)                             0
# Avg RTT UL (ms)                             0
# TCP DL Retrans. Vol (Bytes)                 0
# TCP UL Retrans. Vol (Bytes)                 0
# DL TP < 50 Kbps (%)                         0
# 50 Kbps < DL TP < 250 Kbps (%)              0
# 250 Kbps < DL TP < 1 Mbps (%)               0
# DL TP > 1 Mbps (%)                          0
# UL TP < 10 Kbps (%)                         0
# 10 Kbps < UL TP < 50 Kbps (%)               0
# 50 Kbps < UL TP < 300 Kbps (%)              0
# UL TP > 300 Kbps (%)                        0
# HTTP DL (Bytes)                             0
# HTTP UL (Bytes)                             0
# Nb of sec with 125000B < Vol DL             0
# Nb of sec with 1250B < Vol UL < 6250B       0
# Nb of sec with 31250B < Vol DL < 125000B    0
# Nb of sec with 37500B < Vol UL              0
# Nb of sec with 6250B < Vol DL < 31250B      0
# Nb of sec with 6250B < Vol UL < 37500B      0
# Nb of sec with Vol DL < 6250B               0
# Nb of sec with Vol UL < 1250B               0
# dtype: int64

# %%
for var in ['Dur. (ms)','Other DL (Bytes)','Other UL (Bytes)','Total UL (Bytes)','Total DL (Bytes)','Gaming UL (Bytes)','Gaming DL (Bytes)','Netflix UL (Bytes)','Netflix DL (Bytes)','Youtube UL (Bytes)','Youtube DL (Bytes)','Email UL (Bytes)','Email DL (Bytes)','Google UL (Bytes)','Google DL (Bytes)','Social Media UL (Bytes)','Social Media DL (Bytes)',]:
    print(tele[var].describe())
# Out:
# count    1.500000e+05
# mean     1.046086e+05
# std      8.103762e+04
# min      7.142000e+03
# 25%      5.744050e+04
# 50%      8.639900e+04
# 75%      1.324302e+05
# max      1.859336e+06
# Name: Dur. (ms), dtype: float64
# count    1.500010e+05
# mean     4.211005e+08
# std      2.432050e+08
# min      3.290000e+03
# 25%      2.101869e+08
# 50%      4.218030e+08
# 75%      6.316918e+08
# max      8.434425e+08
# Name: Other DL (Bytes), dtype: float64
# count    1.500010e+05
# mean     8.264799e+06
# std      4.769004e+06
# min      1.480000e+02
# 25%      4.145943e+06
# 50%      8.267071e+06
# 75%      1.238415e+07
# max      1.655882e+07
# Name: Other UL (Bytes), dtype: float64
# count    1.500000e+05
# mean     4.112121e+07
# std      1.127639e+07
# min      2.866892e+06
# 25%      3.322201e+07
# 50%      4.114331e+07
# 75%      4.903424e+07
# max      7.833131e+07
# Name: Total UL (Bytes), dtype: float64
# count    1.500000e+05
# mean     4.546434e+08
# std      2.441429e+08
# min      7.114041e+06
# 25%      2.431068e+08
# 50%      4.558411e+08
# 75%      6.657055e+08
# max      9.029696e+08
# Name: Total DL (Bytes), dtype: float64
# count    1.500010e+05
# mean     8.288398e+06
# std      4.782700e+06
# min      5.900000e+01
# 25%      4.128476e+06
# 50%      8.291208e+06
# 75%      1.243162e+07
# max      1.655879e+07
# Name: Gaming UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     4.220447e+08
# std      2.439675e+08
# min      2.516000e+03
# 25%      2.104733e+08
# 50%      4.234081e+08
# 75%      6.331742e+08
# max      8.434419e+08
# Name: Gaming DL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.100175e+07
# std      6.359490e+06
# min      3.500000e+01
# 25%      5.475981e+06
# 50%      1.099638e+07
# 75%      1.650727e+07
# max      2.201196e+07
# Name: Netflix UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.162685e+07
# std      6.725218e+06
# min      4.200000e+01
# 25%      5.777156e+06
# 50%      1.164222e+07
# 75%      1.747048e+07
# max      2.325919e+07
# Name: Netflix DL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.100941e+07
# std      6.345423e+06
# min      1.050000e+02
# 25%      5.517965e+06
# 50%      1.101345e+07
# 75%      1.651556e+07
# max      2.201196e+07
# Name: Youtube UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.163407e+07
# std      6.710569e+06
# min      5.300000e+01
# 25%      5.833501e+06
# 50%      1.161602e+07
# 75%      1.744852e+07
# max      2.325910e+07
# Name: Youtube DL (Bytes), dtype: float64
# count    150001.000000
# mean     467373.441940
# std      269969.307031
# min           2.000000
# 25%      233383.000000
# 50%      466250.000000
# 75%      700440.000000
# max      936418.000000
# Name: Email UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.791729e+06
# std      1.035840e+06
# min      1.400000e+01
# 25%      8.927930e+05
# 50%      1.793505e+06
# 75%      2.689327e+06
# max      3.586146e+06
# Name: Email DL (Bytes), dtype: float64
# count    1.500010e+05
# mean     2.056542e+06
# std      1.189917e+06
# min      3.000000e+00
# 25%      1.024279e+06
# 50%      2.054573e+06
# 75%      3.088454e+06
# max      4.121357e+06
# Name: Google UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     5.750753e+06
# std      3.309097e+06
# min      2.070000e+02
# 25%      2.882393e+06
# 50%      5.765829e+06
# 75%      8.623552e+06
# max      1.146283e+07
# Name: Google DL (Bytes), dtype: float64
# count    150001.000000
# mean      32928.434380
# std       19006.178256
# min           0.000000
# 25%       16448.000000
# 50%       32920.000000
# 75%       49334.000000
# max       65870.000000
# Name: Social Media UL (Bytes), dtype: float64
# count    1.500010e+05
# mean     1.795322e+06
# std      1.035482e+06
# min      1.200000e+01
# 25%      8.991480e+05
# 50%      1.794369e+06
# 75%      2.694938e+06
# max      3.586064e+06
# Name: Social Media DL (Bytes), dtype: float64

# %%
#we will find the mode of the columns
for var in ['Dur. (ms)','Other DL (Bytes)','Other UL (Bytes)','Total UL (Bytes)','Total DL (Bytes)','Gaming UL (Bytes)','Gaming DL (Bytes)','Netflix UL (Bytes)','Netflix DL (Bytes)','Youtube UL (Bytes)','Youtube DL (Bytes)','Email UL (Bytes)','Email DL (Bytes)','Google UL (Bytes)','Google DL (Bytes)','Social Media UL (Bytes)','Social Media DL (Bytes)',]:
    print(tele[var].mode()[0])
# Out:
# 86399.0
# 28616268.0
# 4514572.0
# 19362459.0
# 74126119.0
# 15304673.0
# 88731721.0
# 1751610.0
# 2097111.0
# 3398443.0
# 18869169.0
# 53137.0
# 1829513.0
# 3426526.0
# 3991481.0
# 30810.0
# 152013.0

# %%
#we will find the median of the columns
for var in ['Dur. (ms)','Other DL (Bytes)','Other UL (Bytes)','Total UL (Bytes)','Total DL (Bytes)','Gaming UL (Bytes)','Gaming DL (Bytes)','Netflix UL (Bytes)','Netflix DL (Bytes)','Youtube UL (Bytes)','Youtube DL (Bytes)','Email UL (Bytes)','Email DL (Bytes)','Google UL (Bytes)','Google DL (Bytes)','Social Media UL (Bytes)','Social Media DL (Bytes)',]:
    print(tele[var].median())
# Out:
# 86399.0
# 421803006.0
# 8267071.0
# 41143312.0
# 455841077.5
# 8291208.0
# 423408104.0
# 10996384.0
# 11642217.0
# 11013447.0
# 11616019.0
# 466250.0
# 1793505.0
# 2054573.0
# 5765829.0
# 32920.0
# 1794369.0

# %% [markdown]
# # Graphical Univariate analysis

# %%
# list of continuous variables
cont_vars = [var for var in num_vars if var not in discrete_vars+year_vars+['Id']]

print('Number of continuous variables: ', len(cont_vars))
# Out:
# Number of continuous variables:  51

# %%
# Let's go ahead and analyse the distributions of these variables
def analyse_continous(df, var):
    df = df.copy()
    df[var].hist(bins=20)
    plt.xlabel(var)
    plt.title(var)
    plt.show()
    
for var in cont_vars:
    analyse_continous(tele, var)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
vars=['Gaming UL (Bytes)','Gaming DL (Bytes)','Netflix UL (Bytes)','Netflix DL (Bytes)','Youtube UL (Bytes)','Youtube DL (Bytes)','Email UL (Bytes)','Email DL (Bytes)','Google UL (Bytes)','Google DL (Bytes)','Social Media UL (Bytes)','Social Media DL (Bytes)']
def analyse(df, var):
    df = df.copy()
    df.groupby(var)[['Total UL (Bytes)']+['Total DL (Bytes)']].plot.bar()
    plt.title(var)
    plt.ylabel('Total UL (Bytes)' + 'Total DL (Bytes)')
    plt.show()
    
for var in vars:
    analyse(tele, var)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\plotting\_core.py:304: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
# let's make boxplots to visualise outliers in the continuous variables 

def find_outliers(df, var):
    
    df.boxplot(var)
    plt.title(var)
    plt.ylabel(var)
    plt.show()
    
for var in ['Dur. (ms)','Other DL (Bytes)','Other UL (Bytes)','Total UL (Bytes)','Total DL (Bytes)','Gaming UL (Bytes)','Gaming DL (Bytes)','Netflix UL (Bytes)','Netflix DL (Bytes)','Youtube UL (Bytes)','Youtube DL (Bytes)','Email UL (Bytes)','Email DL (Bytes)','Google UL (Bytes)','Google DL (Bytes)','Social Media UL (Bytes)','Social Media DL (Bytes)',]:
    find_outliers(tele, var)

# %%
def analyse_discrete(df, var):
    df = df.copy()
    df.groupby(var)['Total DL (Bytes)','Total UL (Bytes)'].median().plot.bar()
    plt.title(var)
    plt.ylabel('Total DL (Bytes)')
    plt.show()
    
for var in discrete_vars:
    analyse_discrete(tele, var)

# %% [markdown]
# # Capping Outliers

# %%
def find_normal_boundaries(df, variable, distance):

    # calculate the boundaries outside which sit the outliers
    # for a Gaussian distribution

    upper_boundary = df[variable].mean() + distance * df[variable].std()
    lower_boundary = df[variable].mean() - distance * df[variable].std()

    return upper_boundary, lower_boundary

# %%
# find limits Dur. (ms)
Dur_upper_limit, Dur_lower_limit = find_normal_boundaries(tele, 'Dur. (ms)', 1.5)
Dur_upper_limit, Dur_lower_limit
# Out:
# (226164.99256513722, -16947.8718718039)

# %%
# find limits Total UL (Bytes)

Total_UL_upper_limit, Total_UL_lower_limit = find_normal_boundaries(tele, 'Total UL (Bytes)', 1.5)
Total_UL_upper_limit, Total_UL_lower_limit
# Out:
# (58035786.06414018, 24206626.520073153)

# %%
# Now let's replace the outliers by the maximum and minimum limit

tele['Dur. (ms)']= np.where(tele['Dur. (ms)'] > Dur_upper_limit, Dur_upper_limit,
                       np.where(tele['Dur. (ms)'] < Dur_lower_limit, Dur_lower_limit, tele['Dur. (ms)']))

# %%
# Now let's replace the outliers by the maximum and minimum limit

tele['Total UL (Bytes)']= np.where(tele['Total UL (Bytes)'] > Total_UL_upper_limit, Total_UL_upper_limit,
                       np.where(tele['Total UL (Bytes)'] < Total_UL_lower_limit, Total_UL_lower_limit, tele['Total UL (Bytes)']))

# %%
def find_outliers(df, var):
    
    df.boxplot(var)
    plt.title(var)
    plt.ylabel(var)
    plt.show()
    
for var in ['Dur. (ms)','Total UL (Bytes)']:
    find_outliers(tele, var)
